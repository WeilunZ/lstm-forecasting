# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import math

# %%
# 读取数据，pd.read_csv默认生成DataFrame对象，需将其转换成Series对象
df_ori = pd.read_csv('../../dataset/GOOGL-year.csv',header=0)
df_ori.index = pd.to_datetime(df_ori['Date'])  # 将字符串索引转换成时间索引
#df=df_ori.asfreq(freq='3d',method='ffill')
df_ori.head()
# Out:
#                   Date         Open         High          Low        Close  \
# Date
# 2018-02-02  2018-02-02  1127.420044  1131.300049  1111.170044  1119.199951
# 2018-02-05  2018-02-05  1100.609985  1114.989990  1056.739990  1062.390015
# 2018-02-06  2018-02-06  1033.979980  1087.380005  1030.010010  1084.430054
# 2018-02-07  2018-02-07  1084.969971  1086.530029  1054.619995  1055.410034
# 2018-02-08  2018-02-08  1059.869995  1063.930054  1004.700012  1007.710022
#
#               Adj Close   Volume
# Date
# 2018-02-02  1119.199951  5892100
# 2018-02-05  1062.390015  4177500
# 2018-02-06  1084.430054  3831500
# 2018-02-07  1055.410034  2597100
# 2018-02-08  1007.710022  3339600

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
sc_close=sc.fit_transform(df_ori['Close'].values.reshape(-1,1))

# %%
def data_to_x_y(data,n_in_steps,n_out_steps):
    X_data,y_data=[],[]
    for i in range(0,data.shape[0]-n_in_steps-n_out_steps):
        X_data.append(data[i:i+n_in_steps])
        y_data.append(data[i+n_in_steps+n_out_steps-1])
    X_data=np.array(X_data)
    y_data=np.array(y_data)
    #X_data=X_data.reshape(X_train.shape[0],X_train.shape[1],1)
    #y_data=y_data.reshape(y_train.shape[0],1)
    return X_data,y_data

# %%
X_train,y_train=data_to_x_y(sc_close,5,1)
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1])
y_train=y_train.reshape(y_train.shape[0])
print(X_train.shape)
print(y_train.shape)
# Out:
# (245, 5)
# (245,)

# %%
X=np.array([x for x in range(sc_close.shape[0])]).reshape(-1,1)
Y=sc_close

# %%
#SVR Model
svr_rbf = SVR(kernel='rbf', C=10,gamma=12)
#svr_lin = SVR(kernel='linear', C=1e3)
#svr_poly = SVR(kernel='poly', C=1e3, degree=2)
rbf_fit = svr_rbf.fit(X_train, y_train)
# lin_fit = svr_lin.fit(X_train,y_train)
# poly_fit = svr_poly.fit(X_train, y_train)

# %%
#训练集拟合
ypre=rbf_fit.predict(X_train)
plt.figure(figsize=(20,10))
plt.plot(ypre,color='blue',lw=1,label='fitting')
plt.plot(y_train,color='red',lw=1,label='origin')
plt.show()

# %%
predictions=list()
days=60
timestep=5
tst=X_train.copy()
tst_r=tst[-1]
ypre_all=ypre.copy()

for i in range(days):
    testX=np.transpose(tst_r[-timestep:].reshape(-1,1))
    yhat=rbf_fit.predict(testX)
    tst_r=np.append(tst_r,yhat[0])
    ypre_all=np.append(ypre_all,yhat[0])
    predictions.append(yhat[0])
print(predictions)
# Out:
# (5,)
# [0.3883538]
# [[0.38839218 0.31642455 0.28384826 0.37669116 0.3883538 ]]
# [[0.31642455 0.28384826 0.37669116 0.3883538  0.3883538 ]]
# [[0.28384826 0.37669116 0.3883538  0.3883538  0.3883538 ]]
# [[0.37669116 0.3883538  0.3883538  0.3883538  0.3883538 ]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [[0.3883538 0.3883538 0.3883538 0.3883538 0.3883538]]
# [0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834, 0.388353802045834]

# %%
'''
predictions=list()
days=60
timestep=5
test=ypre.copy()
#testX=[k+1 for k in X]
for i in range(days):
    X_test=np.transpose(test[-timestep:])
    yhat=rbf_fit.predict(X_test.reshape(1,-1))
    #test=np.vstack((test,yhat))
    #yhat=rbf_fit.predict(testX)
    #testX=[k+1 for k in testX]
    test=np.append(test,yhat)
    rbf_fit = svr_rbf.fit(X_train, y_train)
    #print(test.shape)
    #print(predictions)
    #predictions.append(yhat[-1])
    predictions.append(yhat[0])
# ypre_new=ypre.copy()

# X_test_reshape=np.array(np.array(X_test).reshape(-1,1))
# yhat=rbf_fit.predict(X_test_reshape)
# ypre_new=np.append(ypre_new,yhat[-days:])
# predictions.append(yhat)
'''
# Out:
# '\npredictions=list()\ndays=60\ntimestep=5\ntest=ypre.copy()\n#testX=[k+1 for k in X]\nfor i in range(days):\n    X_test=np.transpose(test[-timestep:])\n    yhat=rbf_fit.predict(X_test.reshape(1,-1))\n    #test=np.vstack((test,yhat))\n    #yhat=rbf_fit.predict(testX)\n    #testX=[k+1 for k in testX]\n    test=np.append(test,yhat)\n    rbf_fit = svr_rbf.fit(X_train, y_train)\n    #print(test.shape)\n    #print(predictions)\n    #predictions.append(yhat[-1])\n    predictions.append(yhat[0])\n# ypre_new=ypre.copy()\n\n# X_test_reshape=np.array(np.array(X_test).reshape(-1,1))\n# yhat=rbf_fit.predict(X_test_reshape)\n# ypre_new=np.append(ypre_new,yhat[-days:])\n# predictions.append(yhat)\n'

# %%
print(predictions)
# Out:
# [0.388353802045834, 0.38200600648220134, 0.3416741914277169, 0.28245047046898836, 0.2681138265403658, 0.2822282407075581, 0.3045678718793881, 0.2977116986577058, 0.2461944822653293, 0.21493284586055889, 0.2296449875467384, 0.23293978485529038, 0.22442780987976035, 0.20853335992758765, 0.21590534567993008, 0.21324129426584176, 0.2193288295411236, 0.2136333768831576, 0.22590515994257548, 0.2207685027922766, 0.2304729970074722, 0.21976575993383501, 0.22907151562382239, 0.21647518950320715, 0.22686502099422318, 0.21310492371011575, 0.22677793550425013, 0.21231872162949178, 0.2293228521224016, 0.2128760665521064, 0.23268701657957253, 0.21311626605009187, 0.2350945190024601, 0.21192827790568664, 0.23651358767452663, 0.21009926623176006, 0.2381720233227947, 0.2086084240115545, 0.24082030806350768, 0.2078161822660765, 0.24424293233405853, 0.2073925641911532, 0.24771519932530178, 0.20693158075703738, 0.25076225289396953, 0.20638004067418142, 0.2534058189079545, 0.20595236597417738, 0.2558014209783262, 0.20577857535575889, 0.25790638323029286, 0.20579549640394018, 0.25954879084671606, 0.20586225226139226, 0.26065422093191454, 0.20590007599285648, 0.2613201849341376, 0.2059081744081646, 0.2617115210709476, 0.20591061935918314]

# %%
inv_yhat=sc.inverse_transform(ypre_all.reshape(-1,1))
print(inv_yhat.shape)
# Out:
# (305, 1)

# %%
df_all=pd.read_csv('../../dataset/GOOGL-year-now.csv',header=0)
df_all_close=df_all['Close']
plt.figure(figsize=(20,10))
plt.plot(inv_yhat,color='blue',lw=1,label='prediction')
plt.plot(df_all_close.values,color='red',lw=1,label='Origin')
plt.show()

# %%
#误差统计
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import math
pre=inv_yhat[-days:]
ori=df_all_close.values[inv_yhat.shape[0]-days:inv_yhat.shape[0]]
print(pre.shape)
print(ori.shape)
avg=np.mean(ori)

rmse=math.sqrt(mean_squared_error(pre, ori))
mae=mean_absolute_error(pre,ori)

rmse_error_percentage=rmse/avg
mae_error_percentage=mae/avg
print('TEST RMSE: %.4f' % rmse)
print('TEST MAE: %.4f'% mae)
print("Test RMSE Error Percentage: %.2f/100.00" % (rmse_error_percentage * 100))
print("Test MAE Error Percentage: %.2f/100.00" % (mae_error_percentage * 100))
# Out:
# (60, 1)
# (60,)
# TEST RMSE: 121.3515
# TEST MAE: 110.6881
# Test RMSE Error Percentage: 10.41/100.00
# Test MAE Error Percentage: 9.50/100.00
