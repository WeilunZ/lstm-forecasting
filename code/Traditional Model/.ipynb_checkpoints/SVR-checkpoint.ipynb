# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import math

# %%
# 读取数据，pd.read_csv默认生成DataFrame对象，需将其转换成Series对象
df_ori = pd.read_csv('../../dataset/MA-year.csv',header=0)
df_ori.index = pd.to_datetime(df_ori['Date'])  # 将字符串索引转换成时间索引
#df=df_ori.asfreq(freq='3d',method='ffill')
df_ori.head()
# Out:
#                   Date        Open        High         Low       Close  \
# Date
# 2018-02-08  2018-02-08  168.770004  169.240005  160.460007  160.619995
# 2018-02-09  2018-02-09  161.669998  166.490005  158.570007  165.199997
# 2018-02-12  2018-02-12  166.800003  168.820007  165.580002  168.190002
# 2018-02-13  2018-02-13  167.330002  170.770004  167.009995  170.119995
# 2018-02-14  2018-02-14  169.360001  172.660004  169.000000  172.520004
#
#              Adj Close   Volume
# Date
# 2018-02-08  159.505783  6557700
# 2018-02-09  164.054016  6303000
# 2018-02-12  167.023285  5227400
# 2018-02-13  168.939896  3471000
# 2018-02-14  171.323257  4203700

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
sc_close=sc.fit_transform(df_ori['Close'].values.reshape(-1,1))

# %%
def data_to_x_y(data,n_in_steps,n_out_steps):
    X_data,y_data=[],[]
    for i in range(0,data.shape[0]-n_in_steps-n_out_steps):
        X_data.append(data[i:i+n_in_steps])
        y_data.append(data[i+n_in_steps+n_out_steps-1])
    X_data=np.array(X_data)
    y_data=np.array(y_data)
    #X_data=X_data.reshape(X_train.shape[0],X_train.shape[1],1)
    #y_data=y_data.reshape(y_train.shape[0],1)
    return X_data,y_data

# %%
X_train,y_train=data_to_x_y(sc_close,5,1)
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1])
y_train=y_train.reshape(y_train.shape[0])
print(X_train.shape)
print(y_train.shape)
# Out:
# (246, 5)
# (246,)

# %%
X=np.array([x for x in range(sc_close.shape[0])]).reshape(-1,1)
Y=sc_close

# %%
#SVR Model
svr_rbf = SVR(kernel='rbf', C=1, gamma=0.01)
#svr_lin = SVR(kernel='linear', C=1e3)
#svr_poly = SVR(kernel='poly', C=1e3, degree=2)
rbf_fit = svr_rbf.fit(X_train, y_train)
# lin_fit = svr_lin.fit(X_train,y_train)
# poly_fit = svr_poly.fit(X_train, y_train)

# %%
#训练集拟合
ypre=rbf_fit.predict(X_train)
plt.figure(figsize=(20,10))
plt.plot(ypre,color='blue',lw=1,label='fitting')
plt.plot(y_train,color='red',lw=1,label='origin')
plt.show()

# %%
predictions=list()
days=60
timestep=5
test=sc_close.copy()

for i in range(days):
    X_test=np.transpose(test[-timestep:])
    yhat=rbf_fit.predict(X_test)
#     print(test.shape)
    test=np.vstack((test,yhat))
#     print(test.shape)
    predictions.append(yhat[0])
# ypre_new=ypre.copy()

# X_test_reshape=np.array(np.array(X_test).reshape(-1,1))
# yhat=rbf_fit.predict(X_test_reshape)
# ypre_new=np.append(ypre_new,yhat[-days:])
# predictions.append(yhat)

# %%
print(predictions)
# Out:
# [0.8046515559796125, 0.7919279431166617, 0.7775186777139044, 0.762685983334396, 0.7496973911478269, 0.7307222055448508, 0.7187658401870066, 0.7072834631587939, 0.6964009018141283, 0.6862426806507845, 0.6765836972314507, 0.6681563613299778, 0.66032247446858, 0.6530708191592495, 0.6463851594248461, 0.640230427398791, 0.6346021409216746, 0.6294121494351339, 0.6246321764475578, 0.6202337357936387, 0.616187686430917, 0.6124667355039153, 0.609041319286711, 0.605888835892621, 0.6029879381181389, 0.6003185683219745, 0.5978621451507208, 0.5956014305298393, 0.5935209315952356, 0.5916063043657458, 0.5898443049352741, 0.5882227419732037, 0.5867304035936604, 0.5853569987836135, 0.5840930463825249, 0.5829298180832341, 0.5818592828788132, 0.5808740520236615, 0.5799673275471118, 0.5791328523585522, 0.578364868125157, 0.5776580758631183, 0.5770075992199005, 0.576408950615512, 0.5758580000652777, 0.5753509467768761, 0.574884292919577, 0.5744548194454374, 0.5740595638438356, 0.5736957996824773, 0.5733610177988127, 0.5730529089806178, 0.5727693480253183, 0.5725083790723489, 0.5722682021068024, 0.5720471605400232, 0.5718437297792895, 0.5716565067086556, 0.571484200008649, 0.5713256212476876]

# %%
inv_yhat=sc.inverse_transform(test)
print(inv_yhat.shape)
# Out:
# (312, 1)

# %%
df_all=pd.read_csv('../../dataset/MA-year-now.csv',header=0)
df_all_close=df_all['Close']
plt.figure(figsize=(20,10))
plt.plot(inv_yhat,color='blue',lw=1,label='prediction')
plt.plot(df_all_close.values,color='red',lw=1,label='Origin')
plt.show()

# %%
#误差统计
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import math
pre=inv_yhat[-days:]
ori=df_all_close.values[inv_yhat.shape[0]-days:inv_yhat.shape[0]]
print(pre.shape)
print(ori.shape)
avg=np.mean(ori)

rmse=math.sqrt(mean_squared_error(pre, ori))
mae=mean_absolute_error(pre,ori)

rmse_error_percentage=rmse/avg
mae_error_percentage=mae/avg
print('TEST RMSE: %.4f' % rmse)
print('TEST MAE: %.4f'% mae)
print("Test RMSE Error Percentage: %.2f/100.00" % (rmse_error_percentage * 100))
print("Test MAE Error Percentage: %.2f/100.00" % (mae_error_percentage * 100))
# Out:
# (60, 1)
# (60,)
# TEST RMSE: 39.3950
# TEST MAE: 37.9984
# Test RMSE Error Percentage: 16.89/100.00
# Test MAE Error Percentage: 16.29/100.00
