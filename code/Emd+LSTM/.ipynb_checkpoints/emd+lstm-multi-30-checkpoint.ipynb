# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM,GRU,regularizers
from sklearn import preprocessing                                                                                     
from math import sqrt
from sklearn.metrics import mean_squared_error
import time
import matplotlib.pyplot as plt
import math
import tensorflow as tf

# %%
class Model:
    def __init__(
        self,
        units,
        dropout_rate,
        input_shape,
        loss_funtion,
        optimizer_function
    ):
        self.units=units
        self.dropout_rate=dropout_rate
        self.input_shape=input_shape
        self.loss_function=loss_function
        self.optimizer_function=optimizer_function
    def getModel(self):
#         model = Sequential()
    
#         # Adding the first LSTM layer and some Dropout regularisation
#         model.add(LSTM(units = self.units, return_sequences = True, input_shape = self.input_shape))
#         model.add(Dropout(self.dropout_rate))

#         # Adding a second LSTM layer and some Dropout regularisation
#         model.add(LSTM(units = self.units, return_sequences = True))
#         model.add(Dropout(self.dropout_rate))

#         # Adding a third LSTM layer and some Dropout regularisation
#         model.add(LSTM(units = self.units,return_sequences=True))
#         model.add(Dropout(self.dropout_rate))
        
#         # Adding a fourth LSTM layer and some Dropout regularisation
#         model.add(LSTM(units = self.units))
#         model.add(Dropout(self.dropout_rate))

#         # Adding the output layer
#         model.add(Dense(units = 1))

#         model.compile(loss=self.loss_function, optimizer=self.optimizer_function)
        
        model = Sequential()

        model.add(GRU(self.units, input_shape=self.input_shape))   
        model.add(Dense(1))

        model.compile(loss=self.loss_function, optimizer=self.optimizer_function)

        return model

# %%
def data_to_x_y(data,n_in_steps,n_out_steps):
    X_data,y_data=[],[]
    for i in range(0,data.shape[0]-n_in_steps-n_out_steps):
        X_data.append(data[i:i+n_in_steps])
        y_data.append(data[i+n_in_steps+n_out_steps-1])
    X_data=np.array(X_data)
    y_data=np.array(y_data)
    X_data=X_data.reshape(X_data.shape[0],X_data.shape[1],1)
    y_data=y_data.reshape(y_data.shape[0],1)
    return X_data,y_data

# %%
def train_test_split(X_data,y_data,train_percentage):
    n_train_intervals = math.ceil(X_data.shape[0] * train_percentage) 
    X_train,y_train=X_data[:n_train_intervals],y_data[:n_train_intervals]
    X_test,y_test=X_data[n_train_intervals:],y_data[n_train_intervals:]
    return X_train,y_train,X_test,y_test

# %%
stock_name='HD'

# %%
filepath='../../dataset/emd/'+stock_name+'-5year-emd.csv'
df=pd.read_csv(open(filepath))
future_day=10
timestep=20

# %%
minmax_list=[]
df_log_list=[]
X_train_list,y_train_list=[],[]
X_test_list,y_test_list=[],[]
for i in range(df.shape[1]//2-1,df.shape[1]):
    minmax = MinMaxScaler().fit(df.iloc[:, i].values.reshape(-1,1))
    minmax_list.append(minmax)
    df_log = minmax.transform(df.iloc[:, i].values.reshape(-1,1))
    df_log_list.append(df_log)
    X_data,y_data=data_to_x_y(df_log,timestep,future_day)
    X_train,y_train,X_test,y_test=train_test_split(X_data,y_data,0.7)
    X_train_list.append(X_train)
    y_train_list.append(y_train)
    X_test_list.append(X_test)
    y_test_list.append(y_test)

# %%
print(X_train_list[0].shape)
print(len(X_train_list))
# Out:
# (861, 20, 1)
# 6

# %%
units=8
dropout_rate=0.4
input_shape=(timestep,1)
loss_function='mae'
optimizer_function='adam'
n_batch=20
n_epochs=50

# %%
model_list=[]
for i in range(len(X_train_list)):  #len(X_train_list)
    x_train=X_train_list[i]
    y_train=y_train_list[i]
    x_test=X_test_list[i]
    y_test=y_test_list[i]
    print(x_train.shape)
    model=Model(units,dropout_rate,input_shape,loss_function,optimizer_function).getModel()
    history = model.fit(x_train, y_train,validation_data=(x_test,y_test),epochs=n_epochs, 
                        batch_size=n_batch,verbose=2,shuffle=False)
    model_list.append(model)
    model.save('../../model/%s/emd_10step_%d.h5' % (stock_name,i))
    plt.plot(history.history["loss"] , label="Train Loss (%s)" % 'value')
    plt.plot(history.history["val_loss"], label="Test Loss (%s)" % 'value')
    plt.legend()
    plt.savefig('../../image/EMD/'+stock_name+'/trainloss/'+str(future_day)+'step_trainloss%d.png'% i)
    plt.show()
# Out:
# (861, 20, 1)
# Train on 861 samples, validate on 368 samples
# Epoch 1/50
#  - 13s - loss: 0.7395 - val_loss: 0.5935
# Epoch 2/50
#  - 2s - loss: 0.4747 - val_loss: 0.3214
# Epoch 3/50
#  - 2s - loss: 0.1422 - val_loss: 0.1348
# Epoch 4/50
#  - 2s - loss: 0.0449 - val_loss: 0.1330
# Epoch 5/50
#  - 2s - loss: 0.0445 - val_loss: 0.1326
# Epoch 6/50
#  - 2s - loss: 0.0443 - val_loss: 0.1320
# Epoch 7/50
#  - 2s - loss: 0.0441 - val_loss: 0.1313
# Epoch 8/50
#  - 2s - loss: 0.0438 - val_loss: 0.1306
# Epoch 9/50
#  - 2s - loss: 0.0436 - val_loss: 0.1300
# Epoch 10/50
#  - 2s - loss: 0.0434 - val_loss: 0.1294
# Epoch 11/50
#  - 2s - loss: 0.0432 - val_loss: 0.1286
# Epoch 12/50
#  - 2s - loss: 0.0429 - val_loss: 0.1281
# Epoch 13/50
#  - 2s - loss: 0.0428 - val_loss: 0.1274
# Epoch 14/50
#  - 2s - loss: 0.0425 - val_loss: 0.1268
# Epoch 15/50
#  - 2s - loss: 0.0424 - val_loss: 0.1262
# Epoch 16/50
#  - 2s - loss: 0.0422 - val_loss: 0.1256
# Epoch 17/50
#  - 2s - loss: 0.0420 - val_loss: 0.1250
# Epoch 18/50
#  - 2s - loss: 0.0419 - val_loss: 0.1244
# Epoch 19/50
#  - 2s - loss: 0.0417 - val_loss: 0.1239
# Epoch 20/50
#  - 2s - loss: 0.0417 - val_loss: 0.1234
# Epoch 21/50
#  - 2s - loss: 0.0416 - val_loss: 0.1229
# Epoch 22/50
#  - 2s - loss: 0.0414 - val_loss: 0.1224
# Epoch 23/50
#  - 2s - loss: 0.0412 - val_loss: 0.1220
# Epoch 24/50
#  - 2s - loss: 0.0411 - val_loss: 0.1215
# Epoch 25/50
#  - 2s - loss: 0.0409 - val_loss: 0.1211
# Epoch 26/50
#  - 2s - loss: 0.0410 - val_loss: 0.1207
# Epoch 27/50
#  - 2s - loss: 0.0408 - val_loss: 0.1203
# Epoch 28/50
#  - 2s - loss: 0.0407 - val_loss: 0.1200
# Epoch 29/50
#  - 2s - loss: 0.0406 - val_loss: 0.1196
# Epoch 30/50
#  - 2s - loss: 0.0405 - val_loss: 0.1193
# Epoch 31/50
#  - 2s - loss: 0.0405 - val_loss: 0.1189
# Epoch 32/50
#  - 2s - loss: 0.0404 - val_loss: 0.1186
# Epoch 33/50
#  - 2s - loss: 0.0403 - val_loss: 0.1183
# Epoch 34/50
#  - 2s - loss: 0.0401 - val_loss: 0.1180
# Epoch 35/50
#  - 2s - loss: 0.0401 - val_loss: 0.1177
# Epoch 36/50
#  - 2s - loss: 0.0399 - val_loss: 0.1174
# Epoch 37/50
#  - 2s - loss: 0.0398 - val_loss: 0.1171
# Epoch 38/50
#  - 2s - loss: 0.0400 - val_loss: 0.1168
# Epoch 39/50
#  - 2s - loss: 0.0399 - val_loss: 0.1165
# Epoch 40/50
#  - 2s - loss: 0.0397 - val_loss: 0.1164
# Epoch 41/50
#  - 2s - loss: 0.0398 - val_loss: 0.1160
# Epoch 42/50
#  - 2s - loss: 0.0395 - val_loss: 0.1159
# Epoch 43/50
#  - 2s - loss: 0.0395 - val_loss: 0.1156
# Epoch 44/50
#  - 2s - loss: 0.0394 - val_loss: 0.1155
# Epoch 45/50
#  - 2s - loss: 0.0393 - val_loss: 0.1153
# Epoch 46/50
#  - 2s - loss: 0.0396 - val_loss: 0.1150
# Epoch 47/50
#  - 2s - loss: 0.0392 - val_loss: 0.1149
# Epoch 48/50
#  - 2s - loss: 0.0392 - val_loss: 0.1148
# Epoch 49/50
#  - 2s - loss: 0.0391 - val_loss: 0.1147
# Epoch 50/50
#  - 2s - loss: 0.0390 - val_loss: 0.1145
# (861, 20, 1)
# Train on 861 samples, validate on 368 samples
# Epoch 1/50
#  - 13s - loss: 0.2033 - val_loss: 0.2050
# Epoch 2/50
#  - 2s - loss: 0.0981 - val_loss: 0.2018
# Epoch 3/50
#  - 2s - loss: 0.0965 - val_loss: 0.1995
# Epoch 4/50
#  - 2s - loss: 0.0953 - val_loss: 0.1974
# Epoch 5/50
#  - 2s - loss: 0.0942 - val_loss: 0.1954
# Epoch 6/50
#  - 2s - loss: 0.0931 - val_loss: 0.1935
# Epoch 7/50
#  - 2s - loss: 0.0921 - val_loss: 0.1917
# Epoch 8/50
#  - 2s - loss: 0.0910 - val_loss: 0.1899
# Epoch 9/50
#  - 2s - loss: 0.0900 - val_loss: 0.1881
# Epoch 10/50
#  - 2s - loss: 0.0889 - val_loss: 0.1862
# Epoch 11/50
#  - 2s - loss: 0.0877 - val_loss: 0.1841
# Epoch 12/50
#  - 2s - loss: 0.0863 - val_loss: 0.1817
# Epoch 13/50
#  - 2s - loss: 0.0848 - val_loss: 0.1790
# Epoch 14/50
#  - 2s - loss: 0.0830 - val_loss: 0.1760
# Epoch 15/50
#  - 2s - loss: 0.0813 - val_loss: 0.1727
# Epoch 16/50
#  - 2s - loss: 0.0790 - val_loss: 0.1689
# Epoch 17/50
#  - 2s - loss: 0.0763 - val_loss: 0.1649
# Epoch 18/50
#  - 2s - loss: 0.0736 - val_loss: 0.1606
# Epoch 19/50
#  - 2s - loss: 0.0706 - val_loss: 0.1554
# Epoch 20/50
#  - 2s - loss: 0.0672 - val_loss: 0.1494
# Epoch 21/50
#  - 2s - loss: 0.0636 - val_loss: 0.1433
# Epoch 22/50
#  - 2s - loss: 0.0624 - val_loss: 0.1403
# Epoch 23/50
#  - 2s - loss: 0.0613 - val_loss: 0.1391
# Epoch 24/50
#  - 2s - loss: 0.0598 - val_loss: 0.1393
# Epoch 25/50
#  - 2s - loss: 0.0596 - val_loss: 0.1391
# Epoch 26/50
#  - 2s - loss: 0.0599 - val_loss: 0.1389
# Epoch 27/50
#  - 2s - loss: 0.0590 - val_loss: 0.1389
# Epoch 28/50
#  - 2s - loss: 0.0601 - val_loss: 0.1380
# Epoch 29/50
#  - 2s - loss: 0.0606 - val_loss: 0.1378
# Epoch 30/50
#  - 2s - loss: 0.0598 - val_loss: 0.1378
# Epoch 31/50
#  - 2s - loss: 0.0595 - val_loss: 0.1371
# Epoch 32/50
#  - 2s - loss: 0.0592 - val_loss: 0.1386
# Epoch 33/50
#  - 2s - loss: 0.0582 - val_loss: 0.1378
# Epoch 34/50
#  - 2s - loss: 0.0589 - val_loss: 0.1381
# Epoch 35/50
#  - 2s - loss: 0.0579 - val_loss: 0.1378
# Epoch 36/50
#  - 2s - loss: 0.0583 - val_loss: 0.1372
# Epoch 37/50
#  - 2s - loss: 0.0585 - val_loss: 0.1379
# Epoch 38/50
#  - 2s - loss: 0.0578 - val_loss: 0.1377
# Epoch 39/50
#  - 2s - loss: 0.0578 - val_loss: 0.1379
# Epoch 40/50
#  - 2s - loss: 0.0577 - val_loss: 0.1377
# Epoch 41/50
#  - 2s - loss: 0.0582 - val_loss: 0.1380
# Epoch 42/50
#  - 2s - loss: 0.0576 - val_loss: 0.1379
# Epoch 43/50
#  - 2s - loss: 0.0577 - val_loss: 0.1379
# Epoch 44/50
#  - 2s - loss: 0.0576 - val_loss: 0.1374
# Epoch 45/50
#  - 2s - loss: 0.0581 - val_loss: 0.1380
# Epoch 46/50
#  - 2s - loss: 0.0575 - val_loss: 0.1378
# Epoch 47/50
#  - 2s - loss: 0.0576 - val_loss: 0.1367
# Epoch 48/50
#  - 2s - loss: 0.0580 - val_loss: 0.1380
# Epoch 49/50
#  - 2s - loss: 0.0574 - val_loss: 0.1379
# Epoch 50/50
#  - 2s - loss: 0.0573 - val_loss: 0.1379
# (861, 20, 1)
# Train on 861 samples, validate on 368 samples
# Epoch 1/50
#  - 13s - loss: 0.0544 - val_loss: 0.1071
# Epoch 2/50
#  - 2s - loss: 0.0360 - val_loss: 0.1073
# Epoch 3/50
#  - 2s - loss: 0.0355 - val_loss: 0.1064
# Epoch 4/50
#  - 2s - loss: 0.0352 - val_loss: 0.1055
# Epoch 5/50
#  - 2s - loss: 0.0349 - val_loss: 0.1044
# Epoch 6/50
#  - 2s - loss: 0.0346 - val_loss: 0.1036
# Epoch 7/50
#  - 2s - loss: 0.0343 - val_loss: 0.1026
# Epoch 8/50
#  - 2s - loss: 0.0340 - val_loss: 0.1016
# Epoch 9/50
#  - 2s - loss: 0.0337 - val_loss: 0.1010
# Epoch 10/50
#  - 2s - loss: 0.0334 - val_loss: 0.1003
# Epoch 11/50
#  - 2s - loss: 0.0331 - val_loss: 0.0997
# Epoch 12/50
#  - 2s - loss: 0.0328 - val_loss: 0.0990
# Epoch 13/50
#  - 2s - loss: 0.0324 - val_loss: 0.0982
# Epoch 14/50
#  - 2s - loss: 0.0320 - val_loss: 0.0969
# Epoch 15/50
#  - 2s - loss: 0.0316 - val_loss: 0.0951
# Epoch 16/50
#  - 2s - loss: 0.0311 - val_loss: 0.0931
# Epoch 17/50
#  - 2s - loss: 0.0304 - val_loss: 0.0910
# Epoch 18/50
#  - 2s - loss: 0.0298 - val_loss: 0.0883
# Epoch 19/50
#  - 2s - loss: 0.0292 - val_loss: 0.0859
# Epoch 20/50
#  - 2s - loss: 0.0285 - val_loss: 0.0843
# Epoch 21/50
#  - 2s - loss: 0.0278 - val_loss: 0.0830
# Epoch 22/50
#  - 2s - loss: 0.0269 - val_loss: 0.0821
# Epoch 23/50
#  - 2s - loss: 0.0262 - val_loss: 0.0810
# Epoch 24/50
#  - 2s - loss: 0.0253 - val_loss: 0.0797
# Epoch 25/50
#  - 2s - loss: 0.0243 - val_loss: 0.0781
# Epoch 26/50
#  - 2s - loss: 0.0235 - val_loss: 0.0761
# Epoch 27/50
#  - 2s - loss: 0.0225 - val_loss: 0.0745
# Epoch 28/50
#  - 2s - loss: 0.0220 - val_loss: 0.0716
# Epoch 29/50
#  - 2s - loss: 0.0211 - val_loss: 0.0689
# Epoch 30/50
#  - 2s - loss: 0.0209 - val_loss: 0.0655
# Epoch 31/50
#  - 2s - loss: 0.0200 - val_loss: 0.0625
# Epoch 32/50
#  - 2s - loss: 0.0198 - val_loss: 0.0595
# Epoch 33/50
#  - 2s - loss: 0.0196 - val_loss: 0.0561
# Epoch 34/50
#  - 2s - loss: 0.0186 - val_loss: 0.0549
# Epoch 35/50
#  - 2s - loss: 0.0190 - val_loss: 0.0519
# Epoch 36/50
#  - 2s - loss: 0.0178 - val_loss: 0.0511
# Epoch 37/50
#  - 2s - loss: 0.0188 - val_loss: 0.0484
# Epoch 38/50
#  - 2s - loss: 0.0170 - val_loss: 0.0478
# Epoch 39/50
#  - 2s - loss: 0.0181 - val_loss: 0.0442
# Epoch 40/50
#  - 2s - loss: 0.0174 - val_loss: 0.0441
# Epoch 41/50
#  - 2s - loss: 0.0166 - val_loss: 0.0422
# Epoch 42/50
#  - 2s - loss: 0.0164 - val_loss: 0.0403
# Epoch 43/50
#  - 2s - loss: 0.0158 - val_loss: 0.0396
# Epoch 44/50
#  - 2s - loss: 0.0157 - val_loss: 0.0392
# Epoch 45/50
#  - 2s - loss: 0.0157 - val_loss: 0.0386
# Epoch 46/50
#  - 2s - loss: 0.0158 - val_loss: 0.0382
# Epoch 47/50
#  - 2s - loss: 0.0157 - val_loss: 0.0382
# Epoch 48/50
#  - 2s - loss: 0.0161 - val_loss: 0.0385
# Epoch 49/50
#  - 2s - loss: 0.0165 - val_loss: 0.0386
# Epoch 50/50
#  - 2s - loss: 0.0164 - val_loss: 0.0385
# (861, 20, 1)
# Train on 861 samples, validate on 368 samples
# Epoch 1/50
#  - 13s - loss: 0.6275 - val_loss: 0.4608
# Epoch 2/50
#  - 2s - loss: 0.2067 - val_loss: 0.1199
# Epoch 3/50
#  - 2s - loss: 0.0765 - val_loss: 0.1144
# Epoch 4/50
#  - 2s - loss: 0.0674 - val_loss: 0.1084
# Epoch 5/50
#  - 2s - loss: 0.0620 - val_loss: 0.1031
# Epoch 6/50
#  - 2s - loss: 0.0573 - val_loss: 0.0980
# Epoch 7/50
#  - 2s - loss: 0.0527 - val_loss: 0.0930
# Epoch 8/50
#  - 2s - loss: 0.0483 - val_loss: 0.0881
# Epoch 9/50
#  - 2s - loss: 0.0440 - val_loss: 0.0834
# Epoch 10/50
#  - 2s - loss: 0.0397 - val_loss: 0.0790
# Epoch 11/50
#  - 2s - loss: 0.0357 - val_loss: 0.0749
# Epoch 12/50
#  - 2s - loss: 0.0323 - val_loss: 0.0716
# Epoch 13/50
#  - 2s - loss: 0.0295 - val_loss: 0.0691
# Epoch 14/50
#  - 2s - loss: 0.0276 - val_loss: 0.0667
# Epoch 15/50
#  - 2s - loss: 0.0297 - val_loss: 0.0651
# Epoch 16/50
#  - 2s - loss: 0.0295 - val_loss: 0.0647
# Epoch 17/50
#  - 2s - loss: 0.0290 - val_loss: 0.0639
# Epoch 18/50
#  - 2s - loss: 0.0289 - val_loss: 0.0634
# Epoch 19/50
#  - 2s - loss: 0.0283 - val_loss: 0.0625
# Epoch 20/50
#  - 2s - loss: 0.0280 - val_loss: 0.0614
# Epoch 21/50
#  - 2s - loss: 0.0277 - val_loss: 0.0612
# Epoch 22/50
#  - 2s - loss: 0.0270 - val_loss: 0.0609
# Epoch 23/50
#  - 2s - loss: 0.0268 - val_loss: 0.0606
# Epoch 24/50
#  - 2s - loss: 0.0266 - val_loss: 0.0605
# Epoch 25/50
#  - 2s - loss: 0.0261 - val_loss: 0.0605
# Epoch 26/50
#  - 2s - loss: 0.0258 - val_loss: 0.0602
# Epoch 27/50
#  - 2s - loss: 0.0253 - val_loss: 0.0602
# Epoch 28/50
#  - 2s - loss: 0.0250 - val_loss: 0.0602
# Epoch 29/50
#  - 2s - loss: 0.0248 - val_loss: 0.0601
# Epoch 30/50
#  - 2s - loss: 0.0246 - val_loss: 0.0599
# Epoch 31/50
#  - 2s - loss: 0.0244 - val_loss: 0.0597
# Epoch 32/50
#  - 2s - loss: 0.0242 - val_loss: 0.0595
# Epoch 33/50
#  - 2s - loss: 0.0240 - val_loss: 0.0595
# Epoch 34/50
#  - 2s - loss: 0.0239 - val_loss: 0.0593
# Epoch 35/50
#  - 2s - loss: 0.0237 - val_loss: 0.0593
# Epoch 36/50
#  - 2s - loss: 0.0235 - val_loss: 0.0591
# Epoch 37/50
#  - 2s - loss: 0.0233 - val_loss: 0.0590
# Epoch 38/50
#  - 2s - loss: 0.0232 - val_loss: 0.0588
# Epoch 39/50
#  - 2s - loss: 0.0231 - val_loss: 0.0589
# Epoch 40/50
#  - 2s - loss: 0.0229 - val_loss: 0.0588
# Epoch 41/50
#  - 2s - loss: 0.0227 - val_loss: 0.0590
# Epoch 42/50
#  - 2s - loss: 0.0226 - val_loss: 0.0588
# Epoch 43/50
#  - 2s - loss: 0.0225 - val_loss: 0.0589
# Epoch 44/50
#  - 2s - loss: 0.0223 - val_loss: 0.0588
# Epoch 45/50
#  - 2s - loss: 0.0222 - val_loss: 0.0587
# Epoch 46/50
#  - 2s - loss: 0.0221 - val_loss: 0.0589
# Epoch 47/50
#  - 2s - loss: 0.0220 - val_loss: 0.0589
# Epoch 48/50
#  - 2s - loss: 0.0221 - val_loss: 0.0586
# Epoch 49/50
#  - 2s - loss: 0.0221 - val_loss: 0.0585
# Epoch 50/50
#  - 2s - loss: 0.0220 - val_loss: 0.0583
# (861, 20, 1)
# Train on 861 samples, validate on 368 samples
# Epoch 1/50
#  - 13s - loss: 0.2829 - val_loss: 0.2352
# Epoch 2/50
#  - 2s - loss: 0.1037 - val_loss: 0.1747
# Epoch 3/50
#  - 2s - loss: 0.0883 - val_loss: 0.1562
# Epoch 4/50
#  - 2s - loss: 0.0755 - val_loss: 0.1297
# Epoch 5/50
#  - 2s - loss: 0.0663 - val_loss: 0.1080
# Epoch 6/50
#  - 2s - loss: 0.0571 - val_loss: 0.0866
# Epoch 7/50
#  - 2s - loss: 0.0495 - val_loss: 0.0688
# Epoch 8/50
#  - 2s - loss: 0.0438 - val_loss: 0.0567
# Epoch 9/50
#  - 2s - loss: 0.0406 - val_loss: 0.0505
# Epoch 10/50
#  - 2s - loss: 0.0401 - val_loss: 0.0470
# Epoch 11/50
#  - 2s - loss: 0.0391 - val_loss: 0.0466
# Epoch 12/50
#  - 2s - loss: 0.0401 - val_loss: 0.0429
# Epoch 13/50
#  - 2s - loss: 0.0384 - val_loss: 0.0428
# Epoch 14/50
#  - 2s - loss: 0.0384 - val_loss: 0.0421
# Epoch 15/50
#  - 2s - loss: 0.0380 - val_loss: 0.0418
# Epoch 16/50
#  - 2s - loss: 0.0378 - val_loss: 0.0410
# Epoch 17/50
#  - 2s - loss: 0.0373 - val_loss: 0.0408
# Epoch 18/50
#  - 2s - loss: 0.0371 - val_loss: 0.0405
# Epoch 19/50
#  - 2s - loss: 0.0368 - val_loss: 0.0405
# Epoch 20/50
#  - 2s - loss: 0.0367 - val_loss: 0.0400
# Epoch 21/50
#  - 2s - loss: 0.0363 - val_loss: 0.0398
# Epoch 22/50
#  - 2s - loss: 0.0362 - val_loss: 0.0393
# Epoch 23/50
#  - 2s - loss: 0.0357 - val_loss: 0.0395
# Epoch 24/50
#  - 2s - loss: 0.0357 - val_loss: 0.0393
# Epoch 25/50
#  - 2s - loss: 0.0354 - val_loss: 0.0396
# Epoch 26/50
#  - 2s - loss: 0.0354 - val_loss: 0.0394
# Epoch 27/50
#  - 2s - loss: 0.0351 - val_loss: 0.0394
# Epoch 28/50
#  - 2s - loss: 0.0351 - val_loss: 0.0388
# Epoch 29/50
#  - 2s - loss: 0.0347 - val_loss: 0.0389
# Epoch 30/50
#  - 2s - loss: 0.0345 - val_loss: 0.0390
# Epoch 31/50
#  - 2s - loss: 0.0344 - val_loss: 0.0389
# Epoch 32/50
#  - 2s - loss: 0.0342 - val_loss: 0.0388
# Epoch 33/50
#  - 2s - loss: 0.0341 - val_loss: 0.0387
# Epoch 34/50
#  - 2s - loss: 0.0339 - val_loss: 0.0389
# Epoch 35/50
#  - 2s - loss: 0.0338 - val_loss: 0.0387
# Epoch 36/50
#  - 2s - loss: 0.0336 - val_loss: 0.0385
# Epoch 37/50
#  - 2s - loss: 0.0334 - val_loss: 0.0389
# Epoch 38/50
#  - 2s - loss: 0.0334 - val_loss: 0.0387
# Epoch 39/50
#  - 2s - loss: 0.0332 - val_loss: 0.0385
# Epoch 40/50
#  - 2s - loss: 0.0330 - val_loss: 0.0386
# Epoch 41/50
#  - 2s - loss: 0.0330 - val_loss: 0.0381
# Epoch 42/50
#  - 2s - loss: 0.0325 - val_loss: 0.0392
# Epoch 43/50
#  - 2s - loss: 0.0327 - val_loss: 0.0389
# Epoch 44/50
#  - 2s - loss: 0.0324 - val_loss: 0.0394
# Epoch 45/50
#  - 2s - loss: 0.0323 - val_loss: 0.0397
# Epoch 46/50
#  - 2s - loss: 0.0323 - val_loss: 0.0397
# Epoch 47/50
#  - 2s - loss: 0.0322 - val_loss: 0.0394
# Epoch 48/50
#  - 2s - loss: 0.0321 - val_loss: 0.0387
# Epoch 49/50
#  - 2s - loss: 0.0318 - val_loss: 0.0392
# Epoch 50/50
#  - 2s - loss: 0.0319 - val_loss: 0.0389
# (861, 20, 1)
# Train on 861 samples, validate on 368 samples
# Epoch 1/50
#  - 13s - loss: 0.0011 - val_loss: 0.0386
# Epoch 2/50
#  - 2s - loss: 0.0265 - val_loss: 0.0452
# Epoch 3/50
#  - 2s - loss: 0.0092 - val_loss: 0.0248
# Epoch 4/50
#  - 2s - loss: 3.8076e-04 - val_loss: 0.0195
# Epoch 5/50
#  - 2s - loss: 0.0037 - val_loss: 0.0173
# Epoch 6/50
#  - 2s - loss: 0.0027 - val_loss: 0.0231
# Epoch 7/50
#  - 2s - loss: 0.0022 - val_loss: 0.0162
# Epoch 8/50
#  - 2s - loss: 5.2325e-04 - val_loss: 0.0143
# Epoch 9/50
#  - 2s - loss: 0.0025 - val_loss: 0.0121
# Epoch 10/50
#  - 2s - loss: 0.0072 - val_loss: 0.0193
# Epoch 11/50
#  - 2s - loss: 0.0016 - val_loss: 0.0218
# Epoch 12/50
#  - 2s - loss: 0.0012 - val_loss: 0.0200
# Epoch 13/50
#  - 2s - loss: 0.0012 - val_loss: 0.0185
# Epoch 14/50
#  - 2s - loss: 0.0012 - val_loss: 0.0150
# Epoch 15/50
#  - 2s - loss: 7.7635e-04 - val_loss: 0.0171
# Epoch 16/50
#  - 2s - loss: 0.0037 - val_loss: 0.0139
# Epoch 17/50
#  - 2s - loss: 0.0065 - val_loss: 0.0104
# Epoch 18/50
#  - 2s - loss: 0.0045 - val_loss: 0.0076
# Epoch 19/50
#  - 2s - loss: 0.0112 - val_loss: 0.0137
# Epoch 20/50
#  - 2s - loss: 0.0056 - val_loss: 0.0130
# Epoch 21/50
#  - 2s - loss: 0.0011 - val_loss: 0.0100
# Epoch 22/50
#  - 2s - loss: 0.0096 - val_loss: 0.0078
# Epoch 23/50
#  - 2s - loss: 0.0056 - val_loss: 0.0050
# Epoch 24/50
#  - 2s - loss: 0.0124 - val_loss: 0.0118
# Epoch 25/50
#  - 2s - loss: 0.0047 - val_loss: 0.0080
# Epoch 26/50
#  - 2s - loss: 0.0059 - val_loss: 0.0109
# Epoch 27/50
#  - 2s - loss: 0.0044 - val_loss: 0.0189
# Epoch 28/50
#  - 2s - loss: 0.0029 - val_loss: 0.0138
# Epoch 29/50
#  - 2s - loss: 0.0016 - val_loss: 0.0133
# Epoch 30/50
#  - 2s - loss: 0.0011 - val_loss: 0.0107
# Epoch 31/50
#  - 2s - loss: 0.0064 - val_loss: 0.0089
# Epoch 32/50
#  - 2s - loss: 7.1307e-04 - val_loss: 0.0116
# Epoch 33/50
#  - 2s - loss: 0.0029 - val_loss: 0.0111
# Epoch 34/50
#  - 2s - loss: 9.3886e-04 - val_loss: 0.0155
# Epoch 35/50
#  - 2s - loss: 0.0031 - val_loss: 0.0114
# Epoch 36/50
#  - 2s - loss: 0.0028 - val_loss: 0.0118
# Epoch 37/50
#  - 2s - loss: 8.6049e-04 - val_loss: 0.0124
# Epoch 38/50
#  - 2s - loss: 0.0058 - val_loss: 0.0103
# Epoch 39/50
#  - 2s - loss: 0.0019 - val_loss: 0.0122
# Epoch 40/50
#  - 2s - loss: 0.0011 - val_loss: 0.0140
# Epoch 41/50
#  - 2s - loss: 0.0010 - val_loss: 0.0096
# Epoch 42/50
#  - 2s - loss: 0.0010 - val_loss: 0.0106
# Epoch 43/50
#  - 2s - loss: 0.0042 - val_loss: 0.0114
# Epoch 44/50
#  - 2s - loss: 0.0013 - val_loss: 0.0112
# Epoch 45/50
#  - 2s - loss: 0.0056 - val_loss: 0.0172
# Epoch 46/50
#  - 2s - loss: 0.0018 - val_loss: 0.0176
# Epoch 47/50
#  - 2s - loss: 0.0045 - val_loss: 0.0179
# Epoch 48/50
#  - 2s - loss: 0.0029 - val_loss: 0.0116
# Epoch 49/50
#  - 2s - loss: 7.8975e-04 - val_loss: 0.0155
# Epoch 50/50
#  - 2s - loss: 0.0010 - val_loss: 0.0130

# %%
print(len(model_list))
print(len(X_test_list))
print(len(minmax_list))
# Out:
# 6
# 6
# 6

# %%
#test
comb=np.ones((y_test_list[0].shape[0],y_test_list[0].shape[1]))
for i in range(len(model_list)):
    x_test=X_test_list[i]
    y_test=y_test_list[i]
    model=model_list[i]
    ypre=model.predict(x_test,batch_size=n_batch,verbose=1)
    minmax=minmax_list[i]
    inv_yhat=minmax.inverse_transform(ypre.reshape(-1,1))
    inv_ytest=minmax.inverse_transform(y_test.reshape(-1,1))
    comb+=inv_yhat
    plt.figure(figsize=(15,10))
    plt.plot(inv_ytest,label=str(i)+'Origin')
    plt.plot(inv_yhat,label=str(i)+'Predict')
    plt.legend(
        loc = 'upper center',
        bbox_to_anchor = (0.5, -0.05),
        fancybox = True,
        shadow = True,
        ncol = 5,
    )
    plt.title('IMF % dPrediction by EMD+LSTM - %s'%(i,stock_name))
    plt.savefig('../../image/EMD/'+stock_name+'/IMF_fit/'+str(future_day)+'step_IMF%d.png'% i)
    plt.show()
# Out:
# 368/368 [==============================] - 5s 12ms/step
# 368/368 [==============================] - 5s 12ms/step
# 368/368 [==============================] - 5s 12ms/step
# 368/368 [==============================] - 5s 12ms/step
# 368/368 [==============================] - 5s 12ms/step
# 368/368 [==============================] - 5s 12ms/step

# %%
filepath='../../dataset/5year/'+stock_name+'-5year.csv'
df_all=pd.read_csv(open(filepath))
df_all_test=df_all.iloc[-y_test.shape[0]:]['Close']
df_all_test.shape
# Out:
# (368,)

# %%
plt.figure(figsize=(15,10))
plt.plot(comb,label='predict')
plt.plot(df_all_test.values,label='origin')
plt.legend(
        loc = 'upper center',
        bbox_to_anchor = (0.5, -0.05),
        fancybox = True,
        shadow = True,
        ncol = 5,
)
plt.title('Prediction by EMD+LSTM - %s'%stock_name)
plt.savefig('../../image/EMD/'+stock_name+'/result/'+str(future_day)+'step_result.png')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse=math.sqrt(mean_squared_error(comb, df_all_test.values))
mae=mean_absolute_error(comb, df_all_test.values)
avg=np.mean(df_all_test.values)
rmse_error_percentage=rmse/avg
mae_error_percentage=mae/avg
print("")
print("Test Average Value for %s: %.3f" % ('Open', avg))
print("Test Root Mean Square Error: %.3f" % rmse)
print("Test MAE: %.3f" % mae)
print("Test RMSE Error Percentage: %.2f/100.00" % (rmse_error_percentage * 100))
print("Test MAE Error Percentage: %.2f/100.00" % (mae_error_percentage * 100))
# Out:
# Test Average Value for Open: 188.784
# Test Root Mean Square Error: 5.657
# Test MAE: 4.503
# Test RMSE Error Percentage: 3.00/100.00
# Test MAE Error Percentage: 2.39/100.00
