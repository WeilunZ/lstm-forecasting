# %%
from pyhht.emd import EMD
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyhht.visualization import plot_imfs

# %%
# 读取数据
namelist=['GOOGL-5year.csv','BABA-5year.csv']
for name in namelist:
    stock_dir='../../dataset/5year/'+name
    dataset = pd.read_csv(open(stock_dir),header=0)
    dt_open=dataset['Close']
    data = dt_open.values
    s = data.ravel()
    decomposer = EMD(s)               
    #emd
    IMF = decomposer.decompose()
    #print(IMF.shape)
    imf_data = pd.DataFrame(IMF.T)
    imf_data.to_csv('../../dataset/emd/'+name[:-4]+'-emd.csv')
    plot_imfs(s,IMF)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 2
# 3
# 4
# 5
# 6
# 7

# %%
name[:-4]
# Out:
# 'BABA-5year'
