# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy as np

# %%
lena = mpimg.imread('../../image/GOOGL/result.png') # 读取和代码处于同一目录下的 lena.png
# 此时 lena 就已经是一个 np.array 了，可以对它进行任意处理
fig = plt.figure(figsize = (15, 10))
print(lena.shape) #(512, 512, 3)
plt.axvline(675,0.12,0.96,label="1",color='r',linestyle="--")
plt.imshow(lena) # 显示图片
plt.axis('off') # 不显示坐标轴
plt.savefig('../../image/GOOGL/result+vlines.png')
# Out:
# (578, 880, 4)
